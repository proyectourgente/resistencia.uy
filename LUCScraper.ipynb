# %%
import requests
from pprint import pprint
from IPython.core.display import display, HTML
from markdownify import markdownify as md
import json
import re
import urllib.request

# %%
IMPO_ENDPOINT='https://www.impo.com.uy/bases/'
LUC='codigo-penal/9155-1933/'
ARTICULOS=[1, 4, 5, 10, 11,12, 13, 14, 18, 21, 22, 23, 24, 35, 43, 44, 45, 49, 50, 51, 52, 56, 63, 64, 65, 74, 75, 76, 77, 78, 79, 80, 86, 118, 125, 126, 127, 128, 129, 130, 134, 135, 136, 140, 142, 143, 144, 145, 146, 148, 151, 152, 155, 156, 158, 159, 160, 161, 163, 167, 169, 171, 172, 183, 184, 185, 186, 193, 198, 206, 207, 208, 209, 210, 211, 212, 215, 219, 220, 221, 224, 225, 235, 236, 237, 285, 357, 358, 392, 399, 403, 404, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 468, 469, 470, 471, 472, 473, 474, 475, 476]

# %%
def getAnteriorOriginal(notasArticulo):
    anteriorOriginal = {}
    
    if (notasArticulo):
        textosOriginales = md(notasArticulo).split('**TEXTO ORIGINAL:**')
        if len(textosOriginales) > 1:
            
            #Saco de las notas el link y referencia del texto original
            textosOriginales = textosOriginales[1].split(',')
            textosOriginalesSinLinks = md(notasArticulo, strip=['a']).split('**TEXTO ORIGINAL:**')[1].split(',')
            ultimoTextoOriginalSinLink = textosOriginalesSinLinks[0].strip()
            anteriorOriginal['referencia'] = ultimoTextoOriginalSinLink
            anteriorOriginal['link'] = 'https://www.impo.com.uy'+textosOriginales[0].split('](')[1].split(')')[0]

            #Descargo el texto original y lo guardo
            resp = requests.get(url=anteriorOriginal['link'], params=params)
            data = resp.json(strict=False)
            anteriorOriginal['textoArticulo'] = data['textoArticulo']
            anteriorOriginal['textoArticuloMarkdown'] = md(data['textoArticulo'])
    return anteriorOriginal

# %%
params = dict(
    json='true',
)

for articulo in ARTICULOS:
    print('Descargando Artículo '+str(articulo))
    resp = requests.get(url=IMPO_ENDPOINT+LUC+str(articulo), params=params)

    data = json.loads(resp.text, strict=False)
    data['textoArticuloMarkdown'] = md(data['textoArticulo'])
    data['anteriorOriginal'] = getAnteriorOriginal(data.get('notasArticulo', None))
    
    json_file = open('LUC_articulo_'+str(articulo)+'.json', "w")
    json_file.write(json.dumps(data, indent=4))
    json_file.close()
# Out:
# Descargando Artículo 1
# Descargando Artículo 4
# Descargando Artículo 5
# Descargando Artículo 10
# Descargando Artículo 11
# Descargando Artículo 12
# Descargando Artículo 13
# Descargando Artículo 14
# Descargando Artículo 18
# Descargando Artículo 21
# Descargando Artículo 22
# Descargando Artículo 23
# Descargando Artículo 24
# Descargando Artículo 35
# Descargando Artículo 43
# Descargando Artículo 44
# Descargando Artículo 45
# Descargando Artículo 49
# Descargando Artículo 50
# Descargando Artículo 51
# Descargando Artículo 52
# Descargando Artículo 56
# Descargando Artículo 63
# Descargando Artículo 64
# Descargando Artículo 65
# Descargando Artículo 74
# Descargando Artículo 75
# Descargando Artículo 76
# Descargando Artículo 77
# Descargando Artículo 78
# Descargando Artículo 79
# Descargando Artículo 80
# Descargando Artículo 86
# Descargando Artículo 118
# Descargando Artículo 125
# Descargando Artículo 126
# Descargando Artículo 127
# Descargando Artículo 128
# Descargando Artículo 129
# Descargando Artículo 130
# Descargando Artículo 134
# Descargando Artículo 135
# Descargando Artículo 136
# Descargando Artículo 140
# Descargando Artículo 142
# Descargando Artículo 143
# Descargando Artículo 144
# Descargando Artículo 145
# Descargando Artículo 146
# Descargando Artículo 148
# Descargando Artículo 151
# Descargando Artículo 152
# Descargando Artículo 155
# Descargando Artículo 156
# Descargando Artículo 158
# Descargando Artículo 159
# Descargando Artículo 160
# Descargando Artículo 161
# Descargando Artículo 163
# Descargando Artículo 167
# Descargando Artículo 169
# Descargando Artículo 171
# Descargando Artículo 172
# Descargando Artículo 183
# Descargando Artículo 184
# Descargando Artículo 185
# Descargando Artículo 186
# Descargando Artículo 193
# Descargando Artículo 198
# Descargando Artículo 206
# Descargando Artículo 207
# Descargando Artículo 208
# Descargando Artículo 209
# Descargando Artículo 210
# Descargando Artículo 211
# Descargando Artículo 212
# Descargando Artículo 215
# Descargando Artículo 219
# Descargando Artículo 220
# Descargando Artículo 221
# Descargando Artículo 224
# Descargando Artículo 225
# Descargando Artículo 235
# Descargando Artículo 236
# Descargando Artículo 237
# Descargando Artículo 285
# Descargando Artículo 357
# Descargando Artículo 358
# Descargando Artículo 392
# Descargando Artículo 399
# Descargando Artículo 403
# Descargando Artículo 404
# Descargando Artículo 426
# Descargando Artículo 427
# Descargando Artículo 428
# Descargando Artículo 429
# Descargando Artículo 430
# Descargando Artículo 431
# Descargando Artículo 432
# Descargando Artículo 433
# Descargando Artículo 434
# Descargando Artículo 435
# Descargando Artículo 436
# Descargando Artículo 437
# Descargando Artículo 438
# Descargando Artículo 439
# Descargando Artículo 440
# Descargando Artículo 441
# Descargando Artículo 442
# Descargando Artículo 443
# Descargando Artículo 444
# Descargando Artículo 445
# Descargando Artículo 446
# Descargando Artículo 447
# Descargando Artículo 448
# Descargando Artículo 449
# Descargando Artículo 450
# Descargando Artículo 451
# Descargando Artículo 452
# Descargando Artículo 453
# Descargando Artículo 454
# Descargando Artículo 455
# Descargando Artículo 456
# Descargando Artículo 457
# Descargando Artículo 458
# Descargando Artículo 459
# Descargando Artículo 468
# Descargando Artículo 469
# Descargando Artículo 470
# Descargando Artículo 471
# Descargando Artículo 472
# Descargando Artículo 473
# Descargando Artículo 474
# Descargando Artículo 475
# Descargando Artículo 476
